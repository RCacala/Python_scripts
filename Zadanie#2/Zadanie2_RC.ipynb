# %% [markdown]
# # Zadanie domowe #2 - Radosław Cacała

# %% [markdown]
# ## Zadanie #1

# %%
#Task #1
a = 120130140150160170

a_str = str(a)
zero_count = a_str.count('0')

print("Number of zeros:", zero_count)
# Out:
# Number of zeros: 6

# %% [markdown]
# ## Zadanie #2

# %%
#Task #2
x = 5
print(x == 5 and 3 + 8)   # zwraca 3+8, bo x==5 - True
print(x == 4 and 3 + 8)   # Zwraca False, reszty nie sprawdza
print(3 + 8 and x == 5)   # 11 interpretuje jako True, więc zwraca drugą wartość: True
print(3 + 8 and x == 4)   # 11 interpretuje jako True, więc zwraca drugą wartość: False
print(isinstance(True, int)) # Klasa bool jest pochodną int, True może zachowywac się jak int = 1)
print(isinstance(True, bool)) # True bespośrednio należy do klasy bool
# Out:
# 11
# False
# True
# False
# True
# True

# %% [markdown]
# ## Zadanie #3

# %%
wynik = sum(x*x for x in range(1, 2028, 2))
print(wynik)
# Out:
# 1390120654

# %% [markdown]
# ## Zadanie #4a

# %%
char = 'Radosław'
utf = char.encode('utf-8')
list(utf)
# Out:
# [82, 97, 100, 111, 115, 197, 130, 97, 119]

# %% [markdown]
# ## Zadanie #4b

# %%
pt = [
    (1, "Hydrogen", "H", 1),
    (2, "Helium", "He", 4),
    (3, "Lithium", "Li", 7),
    (4, "Beryllium", "Be", 9),
    (5, "Boron", "B", 11),
    (6, "Carbon", "C", 12),
    (7, "Nitrogen", "N", 14),
    (8, "Oxygen", "O", 16),
    (9, "Fluorine", "F", 19),
    (10, "Neon", "Ne", 20)
]

print("+---+--------------------+------+----------+")
print("|{:>3}|{:<20}|{:^6}|{:>10}|".format("No.", "Name (en)", "Symbol", "Weight (u)"))
print("+---+--------------------+------+----------+")

for n, name, symbol, weight in pt:
    print("|{:>3}|{:<20}|{:^6}|{:>10}|".format(n, name, symbol, weight))

print("+---+--------------------+------+----------+")
# Out:
# +---+--------------------+------+----------+
# |No.|Name (en)           |Symbol|Weight (u)|
# +---+--------------------+------+----------+
# |  1|Hydrogen            |  H   |         1|
# |  2|Helium              |  He  |         4|
# |  3|Lithium             |  Li  |         7|
# |  4|Beryllium           |  Be  |         9|
# |  5|Boron               |  B   |        11|
# |  6|Carbon              |  C   |        12|
# |  7|Nitrogen            |  N   |        14|
# |  8|Oxygen              |  O   |        16|
# |  9|Fluorine            |  F   |        19|
# | 10|Neon                |  Ne  |        20|
# +---+--------------------+------+----------+

# %% [markdown]
# ## Zadanie #5

# %%
S = 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut \
labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris \
nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit\
esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt \
in culpa qui officia deserunt mollit anim id est laborum.'

S_char = sum(1 for c in S if not c.isspace())
print("Liczba znaków bez spacji: ", S_char)
words = [i.strip(',').strip('.') for i in S.split()]
len_word = len(words)
print("Liczba słów: ", len_word)
max_word = max(words, key=len)
print("Najdłuższe słowo: ", max_word)
sorted_lex = sorted(words)
sorted_len = sorted(words, key=len, reverse=True)
print(sorted_lex)
print(sorted_len)
# Out:
# Liczba znaków bez spacji:  377
# Liczba słów:  68
# Najdłuższe słowo:  reprehenderit
# ['Duis', 'Excepteur', 'Lorem', 'Ut', 'ad', 'adipiscing', 'aliqua', 'aliquip', 'amet', 'anim', 'aute', 'cillum', 'commodo', 'consectetur', 'consequat', 'culpa', 'cupidatat', 'deserunt', 'do', 'dolor', 'dolor', 'dolore', 'dolore', 'ea', 'eiusmod', 'elit', 'enim', 'est', 'et', 'eu', 'ex', 'exercitation', 'fugiat', 'id', 'in', 'in', 'in', 'incididunt', 'ipsum', 'irure', 'labore', 'laboris', 'laborum', 'magna', 'minim', 'mollit', 'nisi', 'non', 'nostrud', 'nulla', 'occaecat', 'officia', 'pariatur', 'proident', 'qui', 'quis', 'reprehenderit', 'sed', 'sint', 'sit', 'sunt', 'tempor', 'ullamco', 'ut', 'ut', 'velitesse', 'veniam', 'voluptate']
# ...

# %% [markdown]
# ## Zadanie #6

# %%
t = (2, 4)
print(t[2]) #tuple index out of range, python numeruje od 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 t = (2, 4)
# ----> 2 print(t[2])
#
# IndexError: tuple index out of range

# %%
t.append(6) #'tuple' object has no attribute 'append', krotka jest niemodyfikowalna
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 t.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
a, b = t ; print(a, b) #rozpakowywanie krotki
# Out:
# 2 4

# %% [markdown]
# ## Zadanie #7

# %%
roman_1 = {
    "I": 1,
    "IV": 4,
    "V": 5,
    "IX": 9,
    "X": 10,
    "XL": 40,
    "L": 50,
    "XC": 90,
    "C": 100,
    "CD": 400,
    "D": 500,
    "CM": 900,
    "M": 1000
}

roman_2 = dict([
    ("I", 1),
    ("IV", 4),
    ("V", 5),
    ("IX", 9),
    ("X", 10),
    ("XL", 40),
    ("L", 50),
    ("XC", 90),
    ("C", 100),
    ("CD", 400),
    ("D", 500),
    ("CM", 900),
    ("M", 1000)
])

symbols = ["I","IV","V","IX","X","XL","L","XC","C","CD","D","CM","M"]
values  = [1,4,5,9,10,40,50,90,100,400,500,900,1000]

roman_3 = dict(zip(symbols, values))
