# %% [markdown]
# # Zadanie domowe #10- Radosław Cacała

# %% [markdown]
# ## Zadanie #1

# %% [raw]
# Windows PowerShell
# Copyright (C) Microsoft Corporation. All rights reserved.
#
# Install the latest PowerShell for new features and improvements! https://aka.ms/PSWindows
#
# PS C:\Users\435797\conda\DATA> python3 -m venv course_env
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.
#
# PS C:\Users\435797\conda\DATA> Set-ExecutionPolicy -Scope CurrentUser RemoteSigned
#
# PS C:\Users\435797\conda\DATA> .\course_env\Scripts\Activate.ps1
#
# (course_env) PS C:\Users\435797\conda\DATA> python -m pip install --upgrade pip
# Requirement already satisfied: pip in c:\users\435797\conda\data\course_env\lib\site-packages (24.3.1)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/pip/
# Collecting pip
#   Downloading pip-26.1.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.5 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# Successfully installed pip-26.1.1
#
# (course_env) PS C:\Users\435797\conda\DATA> pip install numpy matplotlib pandas
# Collecting numpy
#   Downloading numpy-2.4.5-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting pandas
#   Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Collecting packaging>=20.0 (from matplotlib)
#   Downloading packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading numpy-2.4.5-cp313-cp313-win_amd64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 757.2 kB/s  0:00:16
# Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 372.1 kB/s  0:00:21
# Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 1.1 MB/s  0:00:09
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 1.7 MB/s  0:00:01
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading packaging-26.2-py3-none-any.whl (100 kB)
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 5.2/7.1 MB 506.9 kB/s eta 0:00:04
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (5.2 MB/7.1 MB, attempt 1)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='files.pythonhosted.org', port=443): Failed to resolve 'files.pythonhosted.org' ([Errno 11001] getaddrinfo failed)")': /packages/3f/82/8a3739a5e470b3c6cbb1d21d315800d8e16bff503d1f16b03a4ec3212786/pillow-12.2.0-cp313-cp313-win_amd64.whl
# Resuming download pillow-12.2.0-cp313-cp313-win_amd64.whl (5.2 MB/7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 1.1 MB/s  0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: tzdata, six, pyparsing, pillow, packaging, numpy, kiwisolver, fonttools, cycler, python-dateutil, contourpy, pandas, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 numpy-2.4.5 packaging-26.2 pandas-3.0.3 pillow-12.2.0 pyparsing-3.3.2 python-dateutil-2.9.0.post0 six-1.17.0 tzdata-2026.2
# (course_env) PS C:\Users\435797\conda\DATA> pip list
# Package         Version
# --------------- -----------
# contourpy       1.3.3
# cycler          0.12.1
# fonttools       4.63.0
# kiwisolver      1.5.0
# matplotlib      3.10.9
# numpy           2.4.5
# packaging       26.2
# pandas          3.0.3
# pillow          12.2.0
# pip             26.1.1
# pyparsing       3.3.2
# python-dateutil 2.9.0.post0
# six             1.17.0
# tzdata          2026.2
# (course_env) PS C:\Users\435797\conda\DATA> deactivate

# %% [markdown]
# ## Zadanie #2

# %%
import numpy as np
import pandas as pd

dates = pd.date_range(
    start="2026-05-01",
    end="2026-05-31",
    freq="D"
)

temperatures = [
    18, 19, 17, 20, 21, 22, 23,
    21, 20, 19, 18, 17, 16, 18,
    19, 20, 22, 23, 24, 25, 24,
    23, 22, 21, 20, 19, 18, 17,
    18, 19, 20
]

temp_series = pd.Series(data=temperatures, index=dates)

print(temp_series)
# Out:
# 2026-05-01    18
# 2026-05-02    19
# 2026-05-03    17
# 2026-05-04    20
# 2026-05-05    21
# 2026-05-06    22
# 2026-05-07    23
# 2026-05-08    21
# 2026-05-09    20
# 2026-05-10    19
# 2026-05-11    18
# 2026-05-12    17
# 2026-05-13    16
# 2026-05-14    18
# 2026-05-15    19
# 2026-05-16    20
# 2026-05-17    22
# 2026-05-18    23
# 2026-05-19    24
# 2026-05-20    25
# 2026-05-21    24
# 2026-05-22    23
# 2026-05-23    22
# 2026-05-24    21
# 2026-05-25    20
# 2026-05-26    19
# 2026-05-27    18
# 2026-05-28    17
# 2026-05-29    18
# 2026-05-30    19
# 2026-05-31    20
# Freq: D, dtype: int64

# %% [markdown]
# ## Zadanie #3

# %%
import pandas as pd

elements = {
    "Name": [
        "Hydrogen", "Helium", "Lithium", "Beryllium", "Boron", \
        "Carbon", "Nitrogen", "Oxygen", "Fluorine", "Neon"     \
    ],
    "Symbol": [
        "H", "He", "Li", "Be", "B",                            \
        "C", "N", "O", "F", "Ne"                               \
    ],
    "Weight": [
        1.008, 4.0026, 6.94, 9.0122, 10.81,                    \
        12.011, 14.007, 15.999, 18.998, 20.180                 \
    ]
}

elements_df = pd.DataFrame(elements)
elements_df.index = range(1, 11)

print(elements_df)
# Out:
#          Name Symbol   Weight
# 1    Hydrogen      H   1.0080
# 2      Helium     He   4.0026
# 3     Lithium     Li   6.9400
# 4   Beryllium     Be   9.0122
# 5       Boron      B  10.8100
# 6      Carbon      C  12.0110
# 7    Nitrogen      N  14.0070
# 8      Oxygen      O  15.9990
# 9    Fluorine      F  18.9980
# 10       Neon     Ne  20.1800
